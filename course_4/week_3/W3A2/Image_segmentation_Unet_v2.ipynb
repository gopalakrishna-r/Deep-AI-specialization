# %% [markdown]
# # Image Segmentation with U-Net
#
# Welcome to the final assignment of Week 3! You'll be building your own U-Net, a type of CNN designed for quick, precise image segmentation, and using it to predict a label for every single pixel in an image - in this case, an image from a self-driving car dataset.
#
# This type of image classification is called semantic image segmentation. It's similar to object detection in that both ask the question: "What objects are in this image and where in the image are those objects located?," but where object detection labels objects with bounding boxes that may include pixels that aren't part of the object, semantic image segmentation allows you to predict a precise mask for each object in the image by labeling each pixel in the image with its corresponding class. The word “semantic” here refers to what's being shown, so for example the “Car” class is indicated below by the dark blue mask, and "Person" is indicated with a red mask:
#
# <img src="images/carseg.png" style="width:500px;height:250;">
# <caption><center> <u><b>Figure 1</u></b>: Example of a segmented image <br> </center></caption>
#
# As you might imagine, region-specific labeling is a pretty crucial consideration for self-driving cars, which require a pixel-perfect understanding of their environment so they can change lanes and avoid other cars, or any number of traffic obstacles that can put peoples' lives in danger.
#
# By the time you finish this notebook, you'll be able to:
#
# * Build your own U-Net
# * Explain the difference between a regular CNN and a U-net
# * Implement semantic image segmentation on the CARLA self-driving car dataset
# * Apply sparse categorical crossentropy for pixelwise prediction
#
# Onward, to this grand and glorious quest!

# %% [markdown]
# ## Table of Content
#
# - [1 - Packages](#1)
# - [2 - Load and Split the Data](#2)
#     - [2.1 - Split Your Dataset into Unmasked and Masked Images](#2-1)
#     - [2.2 - Preprocess Your Data](#2-2)
# - [3 - U-Net](#3)
#     - [3.1 - Model Details](#3-1)
#     - [3.2 - Encoder (Downsampling Block)](#3-2)
#         - [Exercise 1 - conv_block](#ex-1)
#     - [3.3 - Decoder (Upsampling Block)](#3-3)
#         - [Exercise 2 - upsampling_block](#ex-2)
#     - [3.4 - Build the Model](#3-4)
#         - [Exercise 3 - unet_model](#ex-3)
#     - [3.5 - Set Model Dimensions](#3-5)
#     - [3.6 - Loss Function](#3-6)
#     - [3.7 - Dataset Handling](#3-7)
# - [4 - Train the Model](#4)
#     - [4.1 - Create Predicted Masks](#4-1)
#     - [4.2 - Plot Model Accuracy](#4-2)
#     - [4.3 - Show Predictions](#4-3)

# %% [markdown]
# <a name='1'></a>
# ## 1 - Packages
#
# Run the cell below to import all the libraries you'll need:

# %%
import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout 
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate

from test_utils import summary, comparator

# %%
# !tar cvfz allfiles.tar.gz *
# Out:
# Image_segmentation_Unet_v2.ipynb
# __pycache__/
# __pycache__/test_utils.cpython-36.pyc
# __pycache__/outputs.cpython-36.pyc
# data/
# data/CameraRGB/
# data/CameraRGB/002128.png
# data/CameraRGB/008579.png
# data/CameraRGB/015232.png
# data/CameraRGB/006878.png
# data/CameraRGB/008104.png
# data/CameraRGB/002281.png
# data/CameraRGB/004063.png
# data/CameraRGB/049745.png
# data/CameraRGB/013414.png
# data/CameraRGB/011470.png
# data/CameraRGB/022243.png
# data/CameraRGB/049187.png
# data/CameraRGB/011056.png
# data/CameraRGB/049727.png
# data/CameraRGB/006896.png
# data/CameraRGB/012028.png
# data/CameraRGB/009569.png
# data/CameraRGB/007787.png
# data/CameraRGB/010561.png
# data/CameraRGB/064397.png
# data/CameraRGB/015016.png
# data/CameraRGB/004081.png
# data/CameraRGB/049169.png
# data/CameraRGB/012307.png
# data/CameraRGB/049763.png
# data/CameraRGB/004045.png
# data/CameraRGB/000085.png
# data/CameraRGB/049286.png
# data/CameraRGB/002740.png
# data/CameraRGB/010840.png
# data/CameraRGB/002137.png
# data/CameraRGB/011047.png
# data/CameraRGB/006887.png
# data/CameraRGB/012019.png
# data/CameraRGB/007778.png
# data/CameraRGB/008113.png
# data/CameraRGB/015007.png
# data/CameraRGB/004072.png
# data/CameraRGB/002173.png
# data/CameraRGB/049754.png
# data/CameraRGB/002731.png
# data/CameraRGB/022252.png
# data/CameraRGB/002155.png
# data/CameraRGB/049736.png
# data/CameraRGB/008050.png
# data/CameraRGB/011065.png
# data/CameraRGB/002317.png
# data/CameraRGB/012037.png
# data/CameraRGB/007796.png
# data/CameraRGB/009578.png
# data/CameraRGB/010570.png
# data/CameraRGB/013405.png
# data/CameraRGB/002713.png
# data/CameraRGB/015025.png
# data/CameraRGB/004090.png
# data/CameraRGB/001903.png
# data/CameraRGB/022234.png
# data/CameraRGB/049178.png
# data/CameraRGB/004054.png
# data/CameraRGB/002272.png
# data/CameraRGB/006869.png
# data/CameraRGB/049295.png
# data/CameraRGB/015223.png
# data/CameraRGB/008580.png
# data/CameraRGB/009552.png
# data/CameraRGB/008823.png
# data/CameraRGB/017733.png
# data/CameraRGB/000032.png
# data/CameraRGB/049152.png
# data/CameraRGB/049314.png
# data/CameraRGB/002289.png
# data/CameraRGB/008067.png
# data/CameraRGB/007338.png
# data/CameraRGB/014385.png
# data/CameraRGB/003855.png
# data/CameraRGB/002964.png
# data/CameraRGB/011478.png
# data/CameraRGB/010587.png
# data/CameraRGB/018426.png
# data/CameraRGB/012288.png
# data/CameraRGB/011775.png
# data/CameraRGB/008049.png
# data/CameraRGB/064407.png
# data/CameraRGB/003837.png
# data/CameraRGB/009570.png
# data/CameraRGB/002946.png
# data/CameraRGB/001893.png
# data/CameraRGB/018084.png
# data/CameraRGB/010569.png
# data/CameraRGB/049170.png
# data/CameraRGB/035094.png
# data/CameraRGB/004089.png
# data/CameraRGB/008085.png
# data/CameraRGB/007356.png
# data/CameraRGB/003873.png
# data/CameraRGB/010848.png
# data/CameraRGB/002111.png
# data/CameraRGB/011766.png
# data/CameraRGB/012495.png
# data/CameraRGB/002300.png
# data/CameraRGB/003828.png
# data/CameraRGB/017742.png
# data/CameraRGB/012020.png
# data/CameraRGB/018075.png
# data/CameraRGB/035085.png
# data/CameraRGB/049161.png
# data/CameraRGB/002298.png
# data/CameraRGB/049323.png
# data/CameraRGB/008076.png
# data/CameraRGB/007347.png
# data/CameraRGB/003864.png
# data/CameraRGB/014394.png
# data/CameraRGB/011487.png
# data/CameraRGB/002739.png
# data/CameraRGB/018435.png
# data/CameraRGB/010596.png
# data/CameraRGB/012297.png
# data/CameraRGB/010839.png
# data/CameraRGB/008058.png
# data/CameraRGB/011784.png
# data/CameraRGB/003846.png
# data/CameraRGB/014376.png
# data/CameraRGB/064416.png
# data/CameraRGB/011469.png
# data/CameraRGB/010578.png
# data/CameraRGB/018417.png
# data/CameraRGB/018093.png
# data/CameraRGB/004098.png
# data/CameraRGB/003882.png
# data/CameraRGB/002991.png
# data/CameraRGB/049305.png
# data/CameraRGB/008814.png
# data/CameraRGB/006870.png
# data/CameraRGB/017724.png
# data/CameraRGB/010857.png
# data/CameraRGB/008571.png
# data/CameraRGB/002762.png
# data/CameraRGB/008108.png
# data/CameraRGB/015236.png
# data/CameraRGB/002285.png
# data/CameraRGB/049310.png
# data/CameraRGB/004067.png
# data/CameraRGB/064421.png
# data/CameraRGB/014381.png
# data/CameraRGB/003851.png
# data/CameraRGB/002960.png
# data/CameraRGB/049749.png
# data/CameraRGB/022247.png
# data/CameraRGB/018422.png
# data/CameraRGB/013418.png
# data/CameraRGB/010583.png
# data/CameraRGB/011474.png
# data/CameraRGB/064403.png
# data/CameraRGB/003833.png
# data/CameraRGB/002942.png
# data/CameraRGB/008045.png
# data/CameraRGB/011771.png
# data/CameraRGB/035090.png
# data/CameraRGB/006902.png
# data/CameraRGB/004085.png
# data/CameraRGB/022229.png
# data/CameraRGB/018080.png
# data/CameraRGB/010565.png
# data/CameraRGB/004049.png
# data/CameraRGB/000728.png
# data/CameraRGB/007352.png
# data/CameraRGB/049767.png
# data/CameraRGB/010844.png
# data/CameraRGB/002744.png
# data/CameraRGB/008117.png
# data/CameraRGB/004076.png
# data/CameraRGB/002294.png
# data/CameraRGB/010556.png
# data/CameraRGB/003860.png
# data/CameraRGB/014390.png
# data/CameraRGB/002177.png
# data/CameraRGB/049758.png
# data/CameraRGB/007343.png
# data/CameraRGB/009602.png
# data/CameraRGB/012293.png
# data/CameraRGB/007820.png
# data/CameraRGB/010592.png
# data/CameraRGB/018431.png
# data/CameraRGB/002735.png
# data/CameraRGB/011483.png
# data/CameraRGB/003842.png
# data/CameraRGB/064412.png
# data/CameraRGB/002951.png
# data/CameraRGB/002159.png
# data/CameraRGB/008054.png
# data/CameraRGB/011780.png
# data/CameraRGB/022238.png
# data/CameraRGB/004094.png
# data/CameraRGB/013409.png
# data/CameraRGB/010574.png
# data/CameraRGB/011465.png
# data/CameraRGB/002717.png
# data/CameraRGB/004058.png
# data/CameraRGB/049301.png
# data/CameraRGB/002276.png
# data/CameraRGB/010853.png
# data/CameraRGB/015227.png
# data/CameraRGB/049299.png
# data/CameraRGB/008810.png
# data/CameraRGB/006883.png
# data/CameraRGB/017737.png
# data/CameraRGB/007774.png
# data/CameraRGB/009556.png
# data/CameraRGB/008827.png
# data/CameraRGB/008584.png
# data/CameraRGB/049318.png
# data/CameraRGB/049156.png
# data/CameraRGB/014389.png
# data/CameraRGB/003859.png
# data/CameraRGB/049750.png
# data/CameraRGB/007819.png
# data/CameraRGB/012033.png
# data/CameraRGB/009574.png
# data/CameraRGB/049732.png
# data/CameraRGB/011061.png
# data/CameraRGB/011779.png
# data/CameraRGB/022230.png
# data/CameraRGB/049174.png
# data/CameraRGB/015021.png
# data/CameraRGB/018088.png
# data/CameraRGB/013401.png
# data/CameraRGB/004050.png
# data/CameraRGB/003877.png
# data/CameraRGB/002115.png
# data/CameraRGB/008809.png
# data/CameraRGB/049291.png
# data/CameraRGB/012024.png
# data/CameraRGB/006892.png
# data/CameraRGB/001888.png
# data/CameraRGB/007783.png
# data/CameraRGB/002304.png
# data/CameraRGB/011052.png
# data/CameraRGB/012499.png
# data/CameraRGB/049723.png
# data/CameraRGB/049327.png
# data/CameraRGB/035089.png
# data/CameraRGB/049165.png
# data/CameraRGB/015012.png
# data/CameraRGB/018079.png
# data/CameraRGB/000045.png
# data/CameraRGB/010602.png
# data/CameraRGB/003868.png
# data/CameraRGB/012303.png
# data/CameraRGB/002106.png
# data/CameraRGB/002959.png
# data/CameraRGB/049741.png
# data/CameraRGB/049183.png
# data/CameraRGB/013410.png
# data/CameraRGB/049309.png
# data/CameraRGB/049147.png
# data/CameraRGB/008098.png
# data/CameraRGB/000027.png
# data/CameraRGB/002124.png
# data/CameraRGB/008575.png
# data/CameraRGB/008818.png
# data/CameraRGB/008100.png
# data/CameraRGB/017728.png
# data/CameraRGB/006874.png
# data/CameraRGB/004065.png
# data/CameraRGB/010860.png
# data/CameraRGB/015234.png
# data/CameraRGB/008106.png
# data/CameraRGB/049189.png
# data/CameraRGB/001914.png
# data/CameraRGB/022245.png
# data/CameraRGB/010581.png
# data/CameraRGB/018420.png
# data/CameraRGB/013416.png
# data/CameraRGB/011472.png
# data/CameraRGB/002724.png
# data/CameraRGB/049747.png
# data/CameraRGB/004083.png
# data/CameraRGB/006900.png
# data/CameraRGB/010563.png
# data/CameraRGB/015018.png
# data/CameraRGB/064399.png
# data/CameraRGB/049729.png
# data/CameraRGB/011058.png
# data/CameraRGB/008043.png
# data/CameraRGB/006898.png
# data/CameraRGB/002940.png
# data/CameraRGB/064401.png
# data/CameraRGB/007789.png
# data/CameraRGB/003831.png
# data/CameraRGB/010842.png
# data/CameraRGB/001932.png
# data/CameraRGB/049288.png
# data/CameraRGB/011490.png
# data/CameraRGB/049765.png
# data/CameraRGB/007350.png
# data/CameraRGB/004047.png
# data/CameraRGB/002292.png
# data/CameraRGB/004074.png
# data/CameraRGB/010554.png
# data/CameraRGB/015009.png
# data/CameraRGB/011049.png
# data/CameraRGB/006889.png
# data/CameraRGB/008115.png
# data/CameraRGB/012291.png
# data/CameraRGB/010590.png
# data/CameraRGB/011481.png
# data/CameraRGB/002733.png
# data/CameraRGB/008070.png
# data/CameraRGB/007341.png
# data/CameraRGB/049756.png
# data/CameraRGB/009598.png
# data/CameraRGB/000690.png
# data/CameraRGB/022236.png
# data/CameraRGB/004092.png
# data/CameraRGB/001905.png
# data/CameraRGB/013407.png
# data/CameraRGB/010572.png
# data/CameraRGB/015027.png
# data/CameraRGB/002715.png
# data/CameraRGB/011463.png
# data/CameraRGB/002319.png
# data/CameraRGB/008052.png
# data/CameraRGB/049738.png
# data/CameraRGB/003840.png
# data/CameraRGB/064410.png
# data/CameraRGB/010851.png
# data/CameraRGB/049297.png
# data/CameraRGB/015225.png
# data/CameraRGB/002274.png
# data/CameraRGB/004056.png
# data/CameraRGB/049316.png
# data/CameraRGB/049154.png
# data/CameraRGB/000034.png
# data/CameraRGB/008582.png
# data/CameraRGB/008825.png
# data/CameraRGB/009554.png
# data/CameraRGB/002768.png
# data/CameraRGB/007772.png
# data/CameraRGB/006881.png
# data/CameraRGB/017735.png
# data/CameraRGB/010589.png
# data/CameraRGB/018428.png
# data/CameraRGB/008069.png
# data/CameraRGB/003857.png
# data/CameraRGB/014387.png
# data/CameraRGB/002966.png
# data/CameraRGB/035096.png
# data/CameraRGB/049172.png
# data/CameraRGB/000689.png
# data/CameraRGB/018086.png
# data/CameraRGB/011777.png
# data/CameraRGB/049730.png
# data/CameraRGB/009572.png
# data/CameraRGB/003839.png
# data/CameraRGB/064409.png
# data/CameraRGB/012031.png
# data/CameraRGB/002948.png
# data/CameraRGB/002113.png
# data/CameraRGB/008807.png
# data/CameraRGB/003875.png
# data/CameraRGB/002984.png
# data/CameraRGB/049325.png
# data/CameraRGB/049163.png
# data/CameraRGB/035087.png
# data/CameraRGB/015010.png
# data/CameraRGB/018077.png
# data/CameraRGB/000043.png
# data/CameraRGB/011050.png
# data/CameraRGB/011768.png
# data/CameraRGB/012497.png
# data/CameraRGB/007781.png
# data/CameraRGB/009563.png
# data/CameraRGB/002939.png
# data/CameraRGB/006890.png
# data/CameraRGB/012022.png
# data/CameraRGB/017744.png
# data/CameraRGB/012299.png
# data/CameraRGB/011489.png
# data/CameraRGB/010598.png
# data/CameraRGB/007349.png
# data/CameraRGB/012301.png
# data/CameraRGB/003866.png
# data/CameraRGB/010600.png
# data/CameraRGB/049181.png
# data/CameraRGB/018095.png
# data/CameraRGB/018419.png
# data/CameraRGB/011786.png
# data/CameraRGB/002320.png
# data/CameraRGB/064418.png
# data/CameraRGB/014378.png
# data/CameraRGB/009581.png
# data/CameraRGB/003848.png
# data/CameraRGB/008573.png
# data/CameraRGB/010859.png
# data/CameraRGB/002122.png
# data/CameraRGB/002759.png
# data/CameraRGB/008816.png
# data/CameraRGB/017726.png
# data/CameraRGB/006872.png
# data/CameraRGB/049145.png
# data/CameraRGB/003884.png
# data/CameraRGB/049307.png
# data/CameraRGB/049150.png
# data/CameraRGB/004069.png
# data/CameraRGB/002287.png
# data/CameraRGB/049312.png
# data/CameraRGB/008821.png
# data/CameraRGB/002764.png
# data/CameraRGB/017731.png
# data/CameraRGB/015238.png
# data/CameraRGB/011476.png
# data/CameraRGB/018424.png
# data/CameraRGB/010585.png
# data/CameraRGB/007813.png
# data/CameraRGB/022249.png
# data/CameraRGB/001918.png
# data/CameraRGB/003853.png
# data/CameraRGB/014383.png
# data/CameraRGB/007336.png
# data/CameraRGB/008065.png
# data/CameraRGB/010567.png
# data/CameraRGB/018082.png
# data/CameraRGB/035092.png
# data/CameraRGB/004087.png
# data/CameraRGB/003835.png
# data/CameraRGB/064405.png
# data/CameraRGB/001891.png
# data/CameraRGB/002944.png
# data/CameraRGB/011773.png
# data/CameraRGB/008047.png
# data/CameraRGB/010846.png
# data/CameraRGB/001936.png
# data/CameraRGB/003871.png
# data/CameraRGB/002980.png
# data/CameraRGB/007354.png
# data/CameraRGB/010558.png
# data/CameraRGB/035083.png
# data/CameraRGB/049321.png
# data/CameraRGB/002296.png
# data/CameraRGB/004078.png
# data/CameraRGB/008119.png
# data/CameraRGB/017740.png
# data/CameraRGB/012493.png
# data/CameraRGB/002737.png
# data/CameraRGB/018433.png
# data/CameraRGB/010594.png
# data/CameraRGB/012295.png
# data/CameraRGB/009604.png
# data/CameraRGB/014392.png
# data/CameraRGB/003862.png
# data/CameraRGB/007345.png
# data/CameraRGB/008074.png
# data/CameraRGB/002719.png
# data/CameraRGB/011467.png
# data/CameraRGB/018091.png
# data/CameraRGB/010576.png
# data/CameraRGB/000694.png
# data/CameraRGB/004096.png
# data/CameraRGB/064414.png
# data/CameraRGB/003844.png
# data/CameraRGB/011782.png
# data/CameraRGB/002755.png
# data/CameraRGB/008812.png
# data/CameraRGB/015229.png
# data/CameraRGB/010855.png
# data/CameraRGB/001945.png
# data/CameraRGB/003880.png
# data/CameraRGB/049303.png
# data/CameraRGB/002278.png
# data/CameraRGB/008092.png
# data/CameraRGB/004070.png
# data/CameraRGB/049158.png
# data/CameraRGB/017739.png
# data/CameraRGB/012017.png
# data/CameraRGB/006885.png
# data/CameraRGB/008829.png
# data/CameraRGB/009558.png
# data/CameraRGB/008111.png
# data/CameraRGB/007776.png
# data/CameraRGB/011045.png
# data/CameraRGB/008586.png
# data/CameraRGB/022250.png
# data/CameraRGB/049752.png
# data/CameraRGB/013403.png
# data/CameraRGB/015023.png
# data/CameraRGB/022232.png
# data/CameraRGB/049176.png
# data/CameraRGB/012035.png
# data/CameraRGB/011063.png
# data/CameraRGB/049734.png
# data/CameraRGB/049293.png
# data/CameraRGB/015221.png
# data/CameraRGB/006867.png
# data/CameraRGB/008568.png
# data/CameraRGB/002270.png
# data/CameraRGB/002988.png
# data/CameraRGB/004052.png
# data/CameraRGB/003879.png
# data/CameraRGB/015014.png
# data/CameraRGB/012503.png
# data/CameraRGB/049167.png
# data/CameraRGB/006894.png
# data/CameraRGB/012026.png
# data/CameraRGB/049725.png
# data/CameraRGB/011054.png
# data/CameraRGB/002108.png
# data/CameraRGB/010604.png
# data/CameraRGB/049761.png
# data/CameraRGB/012305.png
# data/CameraRGB/013412.png
# data/CameraRGB/002720.png
# data/CameraRGB/022241.png
# data/CameraRGB/049185.png
# data/CameraRGB/049743.png
# data/CameraRGB/002324.png
# data/CameraRGB/002162.png
# data/CameraRGB/006876.png
# data/CameraRGB/015230.png
# data/CameraRGB/008102.png
# data/CameraRGB/002126.png
# data/CameraRGB/008577.png
# data/CameraRGB/004061.png
# data/CameraRGB/049149.png
# data/CameraRGB/000029.png
# data/CameraRGB/022244.png
# data/CameraRGB/049188.png
# data/CameraRGB/002723.png
# data/CameraRGB/011471.png
# data/CameraRGB/013415.png
# data/CameraRGB/010580.png
# data/CameraRGB/049746.png
# data/CameraRGB/002165.png
# data/CameraRGB/008105.png
# data/CameraRGB/006879.png
# data/CameraRGB/015233.png
# data/CameraRGB/004064.png
# data/CameraRGB/010841.png
# data/CameraRGB/002741.png
# data/CameraRGB/049287.png
# data/CameraRGB/049764.png
# data/CameraRGB/012308.png
# data/CameraRGB/004046.png
# data/CameraRGB/008042.png
# data/CameraRGB/011057.png
# data/CameraRGB/049728.png
# data/CameraRGB/003830.png
# data/CameraRGB/007788.png
# data/CameraRGB/064400.png
# data/CameraRGB/012029.png
# data/CameraRGB/006897.png
# data/CameraRGB/064398.png
# data/CameraRGB/015017.png
# data/CameraRGB/010562.png
# data/CameraRGB/004082.png
# data/CameraRGB/022253.png
# data/CameraRGB/012290.png
# data/CameraRGB/011480.png
# data/CameraRGB/002732.png
# data/CameraRGB/049755.png
# data/CameraRGB/007340.png
# data/CameraRGB/002174.png
# data/CameraRGB/011048.png
# data/CameraRGB/007779.png
# data/CameraRGB/008114.png
# data/CameraRGB/006888.png
# data/CameraRGB/015008.png
# data/CameraRGB/004073.png
# data/CameraRGB/010850.png
# data/CameraRGB/049296.png
# data/CameraRGB/015224.png
# data/CameraRGB/002273.png
# data/CameraRGB/004055.png
# data/CameraRGB/049737.png
# data/CameraRGB/008051.png
# data/CameraRGB/009579.png
# data/CameraRGB/015026.png
# data/CameraRGB/002714.png
# data/CameraRGB/011462.png
# data/CameraRGB/010571.png
# data/CameraRGB/013406.png
# data/CameraRGB/049179.png
# data/CameraRGB/004091.png
# data/CameraRGB/001904.png
# data/CameraRGB/022235.png
# data/CameraRGB/012289.png
# data/CameraRGB/007816.png
# data/CameraRGB/018427.png
# data/CameraRGB/010588.png
# data/CameraRGB/011479.png
# data/CameraRGB/008068.png
# data/CameraRGB/007339.png
# data/CameraRGB/002965.png
# data/CameraRGB/003856.png
# data/CameraRGB/014386.png
# data/CameraRGB/008581.png
# data/CameraRGB/001957.png
# data/CameraRGB/017734.png
# data/CameraRGB/006880.png
# data/CameraRGB/008824.png
# data/CameraRGB/009553.png
# data/CameraRGB/002767.png
# data/CameraRGB/007771.png
# data/CameraRGB/000033.png
# data/CameraRGB/049315.png
# data/CameraRGB/049153.png
# data/CameraRGB/002112.png
# data/CameraRGB/010849.png
# data/CameraRGB/003874.png
# data/CameraRGB/011776.png
# data/CameraRGB/002947.png
# data/CameraRGB/001894.png
# data/CameraRGB/012030.png
# data/CameraRGB/003838.png
# data/CameraRGB/009571.png
# data/CameraRGB/064408.png
# data/CameraRGB/018085.png
# data/CameraRGB/035095.png
# data/CameraRGB/000688.png
# data/CameraRGB/049171.png
# data/CameraRGB/012298.png
# data/CameraRGB/010597.png
# data/CameraRGB/011488.png
# data/CameraRGB/012300.png
# data/CameraRGB/007348.png
# data/CameraRGB/002974.png
# data/CameraRGB/014395.png
# data/CameraRGB/003865.png
# data/CameraRGB/001966.png
# data/CameraRGB/011767.png
# data/CameraRGB/012496.png
# data/CameraRGB/002301.png
# data/CameraRGB/012021.png
# data/CameraRGB/017743.png
# data/CameraRGB/007780.png
# data/CameraRGB/003829.png
# data/CameraRGB/009562.png
# data/CameraRGB/018076.png
# data/CameraRGB/049324.png
# data/CameraRGB/049162.png
# data/CameraRGB/035086.png
# data/CameraRGB/002121.png
# data/CameraRGB/010858.png
# data/CameraRGB/008572.png
# data/CameraRGB/001948.png
# data/CameraRGB/017725.png
# data/CameraRGB/006871.png
# data/CameraRGB/002758.png
# data/CameraRGB/008815.png
# data/CameraRGB/049306.png
# data/CameraRGB/049144.png
# data/CameraRGB/003883.png
# data/CameraRGB/008059.png
# data/CameraRGB/011785.png
# data/CameraRGB/064417.png
# data/CameraRGB/014377.png
# data/CameraRGB/003847.png
# data/CameraRGB/009580.png
# data/CameraRGB/018418.png
# data/CameraRGB/010579.png
# data/CameraRGB/018094.png
# data/CameraRGB/049180.png
# data/CameraRGB/010584.png
# data/CameraRGB/018423.png
# data/CameraRGB/013419.png
# data/CameraRGB/011475.png
# data/CameraRGB/022248.png
# data/CameraRGB/002961.png
# data/CameraRGB/003852.png
# data/CameraRGB/014382.png
# data/CameraRGB/007335.png
# data/CameraRGB/008064.png
# data/CameraRGB/002169.png
# data/CameraRGB/015237.png
# data/CameraRGB/017730.png
# data/CameraRGB/008109.png
# data/CameraRGB/008820.png
# data/CameraRGB/002286.png
# data/CameraRGB/049311.png
# data/CameraRGB/004068.png
# data/CameraRGB/001935.png
# data/CameraRGB/010845.png
# data/CameraRGB/003870.png
# data/CameraRGB/007353.png
# data/CameraRGB/049768.png
# data/CameraRGB/002943.png
# data/CameraRGB/001890.png
# data/CameraRGB/003834.png
# data/CameraRGB/064404.png
# data/CameraRGB/011772.png
# data/CameraRGB/008046.png
# data/CameraRGB/004086.png
# data/CameraRGB/035091.png
# data/CameraRGB/010566.png
# data/CameraRGB/018081.png
# data/CameraRGB/018432.png
# data/CameraRGB/010593.png
# data/CameraRGB/001926.png
# data/CameraRGB/012294.png
# data/CameraRGB/002970.png
# data/CameraRGB/014391.png
# data/CameraRGB/003861.png
# data/CameraRGB/049759.png
# data/CameraRGB/007344.png
# data/CameraRGB/008073.png
# data/CameraRGB/008118.png
# data/CameraRGB/012492.png
# data/CameraRGB/004077.png
# data/CameraRGB/049320.png
# data/CameraRGB/002295.png
# data/CameraRGB/010557.png
# data/CameraRGB/015228.png
# data/CameraRGB/008811.png
# data/CameraRGB/010854.png
# data/CameraRGB/004059.png
# data/CameraRGB/049302.png
# data/CameraRGB/002277.png
# data/CameraRGB/008091.png
# data/CameraRGB/064413.png
# data/CameraRGB/003843.png
# data/CameraRGB/011781.png
# data/CameraRGB/004095.png
# data/CameraRGB/022239.png
# data/CameraRGB/000693.png
# data/CameraRGB/002718.png
# data/CameraRGB/011466.png
# data/CameraRGB/018090.png
# data/CameraRGB/010575.png
# data/CameraRGB/000073.png
# data/CameraRGB/002969.png
# data/CameraRGB/049751.png
# data/CameraRGB/007775.png
# data/CameraRGB/008110.png
# data/CameraRGB/009557.png
# data/CameraRGB/008828.png
# data/CameraRGB/006884.png
# data/CameraRGB/017738.png
# data/CameraRGB/002134.png
# data/CameraRGB/008585.png
# data/CameraRGB/049157.png
# data/CameraRGB/049319.png
# data/CameraRGB/049292.png
# data/CameraRGB/008567.png
# data/CameraRGB/002116.png
# data/CameraRGB/003878.png
# data/CameraRGB/002987.png
# data/CameraRGB/004051.png
# data/CameraRGB/012034.png
# data/CameraRGB/001898.png
# data/CameraRGB/002314.png
# data/CameraRGB/011062.png
# data/CameraRGB/049733.png
# data/CameraRGB/049175.png
# data/CameraRGB/022231.png
# data/CameraRGB/018089.png
# data/CameraRGB/013402.png
# data/CameraRGB/015022.png
# data/CameraRGB/002107.png
# data/CameraRGB/007829.png
# data/CameraRGB/003869.png
# data/CameraRGB/010603.png
# data/CameraRGB/012304.png
# data/CameraRGB/049760.png
# data/CameraRGB/012025.png
# data/CameraRGB/006893.png
# data/CameraRGB/001889.png
# data/CameraRGB/049724.png
# data/CameraRGB/011053.png
# data/CameraRGB/049166.png
# data/CameraRGB/015013.png
# data/CameraRGB/012502.png
# data/CameraRGB/008101.png
# data/CameraRGB/008819.png
# data/CameraRGB/006875.png
# data/CameraRGB/017729.png
# data/CameraRGB/008576.png
# data/CameraRGB/002125.png
# data/CameraRGB/049148.png
# data/CameraRGB/004060.png
# data/CameraRGB/000028.png
# data/CameraRGB/008099.png
# data/CameraRGB/009584.png
# data/CameraRGB/002161.png
# data/CameraRGB/049742.png
# data/CameraRGB/022240.png
# data/CameraRGB/013411.png
# data/CameraRGB/064420.png
# data/CameraRGB/014380.png
# data/CameraRGB/003850.png
# data/CameraRGB/049748.png
# data/CameraRGB/008062.png
# data/CameraRGB/022246.png
# data/CameraRGB/001915.png
# data/CameraRGB/011473.png
# data/CameraRGB/002725.png
# data/CameraRGB/010582.png
# data/CameraRGB/018421.png
# data/CameraRGB/013417.png
# data/CameraRGB/004066.png
# data/CameraRGB/010861.png
# data/CameraRGB/002761.png
# data/CameraRGB/008107.png
# data/CameraRGB/015235.png
# data/CameraRGB/004048.png
# data/CameraRGB/049766.png
# data/CameraRGB/007351.png
# data/CameraRGB/010843.png
# data/CameraRGB/049289.png
# data/CameraRGB/006901.png
# data/CameraRGB/004084.png
# data/CameraRGB/015019.png
# data/CameraRGB/010564.png
# data/CameraRGB/011770.png
# data/CameraRGB/008044.png
# data/CameraRGB/011059.png
# data/CameraRGB/064402.png
# data/CameraRGB/003832.png
# data/CameraRGB/002941.png
# data/CameraRGB/006899.png
# data/CameraRGB/009599.png
# data/CameraRGB/008071.png
# data/CameraRGB/007342.png
# data/CameraRGB/049757.png
# data/CameraRGB/009601.png
# data/CameraRGB/012292.png
# data/CameraRGB/011482.png
# data/CameraRGB/002734.png
# data/CameraRGB/018430.png
# data/CameraRGB/010591.png
# data/CameraRGB/002293.png
# data/CameraRGB/004075.png
# data/CameraRGB/010555.png
# data/CameraRGB/001960.png
# data/CameraRGB/008116.png
# data/CameraRGB/049300.png
# data/CameraRGB/002275.png
# data/CameraRGB/004057.png
# data/CameraRGB/010852.png
# data/CameraRGB/049298.png
# data/CameraRGB/015226.png
# data/CameraRGB/001906.png
# data/CameraRGB/004093.png
# data/CameraRGB/022237.png
# data/CameraRGB/000691.png
# data/CameraRGB/011464.png
# data/CameraRGB/002716.png
# data/CameraRGB/015028.png
# data/CameraRGB/010573.png
# data/CameraRGB/013408.png
# data/CameraRGB/008053.png
# data/CameraRGB/049739.png
# data/CameraRGB/002158.png
# data/CameraRGB/003841.png
# data/CameraRGB/007799.png
# data/CameraRGB/064411.png
# data/CameraRGB/002950.png
# data/CameraRGB/003858.png
# data/CameraRGB/009591.png
# data/CameraRGB/014388.png
# data/CameraRGB/002967.png
# data/CameraRGB/018429.png
# data/CameraRGB/049155.png
# data/CameraRGB/049317.png
# data/CameraRGB/002132.png
# data/CameraRGB/008583.png
# data/CameraRGB/017736.png
# data/CameraRGB/006882.png
# data/CameraRGB/007773.png
# data/CameraRGB/008826.png
# data/CameraRGB/009555.png
# data/CameraRGB/003876.png
# data/CameraRGB/008088.png
# data/CameraRGB/002114.png
# data/CameraRGB/049290.png
# data/CameraRGB/008808.png
# data/CameraRGB/035097.png
# data/CameraRGB/049173.png
# data/CameraRGB/018087.png
# data/CameraRGB/015020.png
# data/CameraRGB/049731.png
# data/CameraRGB/011778.png
# data/CameraRGB/011060.png
# data/CameraRGB/002312.png
# data/CameraRGB/012032.png
# data/CameraRGB/001896.png
# data/CameraRGB/002949.png
# data/CameraRGB/009573.png
# data/CameraRGB/003867.png
# data/CameraRGB/010601.png
# data/CameraRGB/012302.png
# data/CameraRGB/010599.png
# data/CameraRGB/049164.png
# data/CameraRGB/035088.png
# data/CameraRGB/049326.png
# data/CameraRGB/018078.png
# data/CameraRGB/000044.png
# data/CameraRGB/015011.png
# data/CameraRGB/002141.png
# data/CameraRGB/012498.png
# data/CameraRGB/011769.png
# data/CameraRGB/011051.png
# data/CameraRGB/002303.png
# data/CameraRGB/049722.png
# data/CameraRGB/006891.png
# data/CameraRGB/001887.png
# data/CameraRGB/012023.png
# data/CameraRGB/009564.png
# data/CameraRGB/007782.png
# data/CameraRGB/049146.png
# data/CameraRGB/049308.png
# data/CameraRGB/002994.png
# data/CameraRGB/000026.png
# data/CameraRGB/002123.png
# data/CameraRGB/008574.png
# data/CameraRGB/006873.png
# data/CameraRGB/017727.png
# data/CameraRGB/008817.png
# data/CameraRGB/049182.png
# data/CameraRGB/018096.png
# data/CameraRGB/002321.png
# data/CameraRGB/049740.png
# data/CameraRGB/002958.png
# data/CameraRGB/003849.png
# data/CameraRGB/064419.png
# data/CameraRGB/014379.png
# data/CameraRGB/007337.png
# data/CameraRGB/002963.png
# data/CameraRGB/014384.png
# data/CameraRGB/003854.png
# data/CameraRGB/010586.png
# data/CameraRGB/018425.png
# data/CameraRGB/011477.png
# data/CameraRGB/002288.png
# data/CameraRGB/049313.png
# data/CameraRGB/049151.png
# data/CameraRGB/017732.png
# data/CameraRGB/015239.png
# data/CameraRGB/009551.png
# data/CameraRGB/008822.png
# data/CameraRGB/008084.png
# data/CameraRGB/007355.png
# data/CameraRGB/002981.png
# data/CameraRGB/003872.png
# data/CameraRGB/002747.png
# data/CameraRGB/002110.png
# data/CameraRGB/007832.png
# data/CameraRGB/010847.png
# data/CameraRGB/010568.png
# data/CameraRGB/018083.png
# data/CameraRGB/004088.png
# data/CameraRGB/035093.png
# data/CameraRGB/001892.png
# data/CameraRGB/002945.png
# data/CameraRGB/064406.png
# data/CameraRGB/003836.png
# data/CameraRGB/008048.png
# data/CameraRGB/011774.png
# data/CameraRGB/007346.png
# data/CameraRGB/003863.png
# data/CameraRGB/014393.png
# data/CameraRGB/010595.png
# data/CameraRGB/018434.png
# data/CameraRGB/011486.png
# data/CameraRGB/002738.png
# data/CameraRGB/012296.png
# data/CameraRGB/010838.png
# data/CameraRGB/010559.png
# data/CameraRGB/002297.png
# data/CameraRGB/049322.png
# data/CameraRGB/004079.png
# data/CameraRGB/035084.png
# data/CameraRGB/049160.png
# data/CameraRGB/017741.png
# data/CameraRGB/009560.png
# data/CameraRGB/003827.png
# data/CameraRGB/012494.png
# data/CameraRGB/011765.png
# data/CameraRGB/008093.png
# data/CameraRGB/049304.png
# data/CameraRGB/002279.png
# data/CameraRGB/003881.png
# data/CameraRGB/017723.png
# data/CameraRGB/008813.png
# data/CameraRGB/002756.png
# data/CameraRGB/008570.png
# data/CameraRGB/010856.png
# data/CameraRGB/018092.png
# data/CameraRGB/018416.png
# data/CameraRGB/010577.png
# data/CameraRGB/011468.png
# data/CameraRGB/004097.png
# data/CameraRGB/000695.png
# data/CameraRGB/007805.png
# data/CameraRGB/002954.png
# data/CameraRGB/003845.png
# data/CameraRGB/064415.png
# data/CameraRGB/011783.png
# data/CameraRGB/008057.png
# data/CameraRGB/049753.png
# data/CameraRGB/009595.png
# data/CameraRGB/002730.png
# data/CameraRGB/022251.png
# data/CameraRGB/000156.png
# data/CameraRGB/015006.png
# data/CameraRGB/049159.png
# data/CameraRGB/004071.png
# data/CameraRGB/008112.png
# data/CameraRGB/009559.png
# data/CameraRGB/007777.png
# data/CameraRGB/006886.png
# data/CameraRGB/012018.png
# data/CameraRGB/015240.png
# data/CameraRGB/008587.png
# data/CameraRGB/011046.png
# data/CameraRGB/004053.png
# data/CameraRGB/002271.png
# data/CameraRGB/002989.png
# data/CameraRGB/006868.png
# data/CameraRGB/049294.png
# data/CameraRGB/015222.png
# data/CameraRGB/008569.png
# data/CameraRGB/012513.png
# data/CameraRGB/015024.png
# data/CameraRGB/002712.png
# data/CameraRGB/013404.png
# data/CameraRGB/049177.png
# data/CameraRGB/022233.png
# data/CameraRGB/001902.png
# data/CameraRGB/009577.png
# data/CameraRGB/012036.png
# data/CameraRGB/049735.png
# data/CameraRGB/011064.png
# data/CameraRGB/049762.png
# data/CameraRGB/012306.png
# data/CameraRGB/004044.png
# data/CameraRGB/049285.png
# data/CameraRGB/000084.png
# data/CameraRGB/002109.png
# data/CameraRGB/064396.png
# data/CameraRGB/015015.png
# data/CameraRGB/012504.png
# data/CameraRGB/010560.png
# data/CameraRGB/049168.png
# data/CameraRGB/004080.png
# data/CameraRGB/009568.png
# data/CameraRGB/006895.png
# data/CameraRGB/012027.png
# data/CameraRGB/011055.png
# data/CameraRGB/049726.png
# data/CameraRGB/002280.png
# data/CameraRGB/004062.png
# data/CameraRGB/008103.png
# data/CameraRGB/015231.png
# data/CameraRGB/006877.png
# data/CameraRGB/008578.png
# data/CameraRGB/002721.png
# data/CameraRGB/013413.png
# data/CameraRGB/049186.png
# data/CameraRGB/022242.png
# data/CameraRGB/002325.png
# data/CameraRGB/049744.png
# data/.DS_Store
# data/CameraMask/
# data/CameraMask/002128.png
# data/CameraMask/008579.png
# data/CameraMask/015232.png
# data/CameraMask/006878.png
# data/CameraMask/008104.png
# data/CameraMask/002281.png
# data/CameraMask/004063.png
# data/CameraMask/049745.png
# data/CameraMask/013414.png
# data/CameraMask/011470.png
# data/CameraMask/022243.png
# data/CameraMask/049187.png
# data/CameraMask/011056.png
# data/CameraMask/049727.png
# data/CameraMask/006896.png
# data/CameraMask/012028.png
# data/CameraMask/009569.png
# data/CameraMask/007787.png
# data/CameraMask/010561.png
# data/CameraMask/064397.png
# data/CameraMask/015016.png
# data/CameraMask/004081.png
# data/CameraMask/049169.png
# data/CameraMask/012307.png
# data/CameraMask/049763.png
# data/CameraMask/004045.png
# data/CameraMask/000085.png
# data/CameraMask/049286.png
# data/CameraMask/002740.png
# data/CameraMask/010840.png
# data/CameraMask/002137.png
# data/CameraMask/011047.png
# data/CameraMask/006887.png
# data/CameraMask/012019.png
# data/CameraMask/007778.png
# data/CameraMask/008113.png
# data/CameraMask/015007.png
# data/CameraMask/004072.png
# data/CameraMask/002173.png
# data/CameraMask/049754.png
# data/CameraMask/002731.png
# data/CameraMask/022252.png
# data/CameraMask/002155.png
# data/CameraMask/049736.png
# data/CameraMask/008050.png
# data/CameraMask/011065.png
# data/CameraMask/002317.png
# data/CameraMask/012037.png
# data/CameraMask/007796.png
# data/CameraMask/009578.png
# data/CameraMask/010570.png
# data/CameraMask/013405.png
# data/CameraMask/002713.png
# data/CameraMask/015025.png
# data/CameraMask/004090.png
# data/CameraMask/001903.png
# data/CameraMask/022234.png
# data/CameraMask/049178.png
# data/CameraMask/004054.png
# data/CameraMask/002272.png
# data/CameraMask/006869.png
# data/CameraMask/049295.png
# data/CameraMask/015223.png
# data/CameraMask/008580.png
# data/CameraMask/009552.png
# data/CameraMask/008823.png
# data/CameraMask/017733.png
# data/CameraMask/000032.png
# data/CameraMask/049152.png
# data/CameraMask/049314.png
# data/CameraMask/002289.png
# data/CameraMask/008067.png
# data/CameraMask/007338.png
# data/CameraMask/014385.png
# data/CameraMask/003855.png
# data/CameraMask/002964.png
# data/CameraMask/011478.png
# data/CameraMask/010587.png
# data/CameraMask/018426.png
# data/CameraMask/012288.png
# data/CameraMask/011775.png
# data/CameraMask/008049.png
# data/CameraMask/064407.png
# data/CameraMask/003837.png
# data/CameraMask/009570.png
# data/CameraMask/002946.png
# data/CameraMask/001893.png
# data/CameraMask/018084.png
# data/CameraMask/010569.png
# data/CameraMask/049170.png
# data/CameraMask/035094.png
# data/CameraMask/004089.png
# data/CameraMask/008085.png
# data/CameraMask/007356.png
# data/CameraMask/003873.png
# data/CameraMask/010848.png
# data/CameraMask/002111.png
# data/CameraMask/011766.png
# data/CameraMask/012495.png
# data/CameraMask/002300.png
# data/CameraMask/003828.png
# data/CameraMask/017742.png
# data/CameraMask/012020.png
# data/CameraMask/018075.png
# data/CameraMask/035085.png
# data/CameraMask/049161.png
# data/CameraMask/002298.png
# data/CameraMask/049323.png
# data/CameraMask/008076.png
# data/CameraMask/007347.png
# data/CameraMask/003864.png
# data/CameraMask/014394.png
# data/CameraMask/011487.png
# data/CameraMask/002739.png
# data/CameraMask/018435.png
# data/CameraMask/010596.png
# data/CameraMask/012297.png
# data/CameraMask/010839.png
# data/CameraMask/008058.png
# data/CameraMask/011784.png
# data/CameraMask/003846.png
# data/CameraMask/014376.png
# data/CameraMask/064416.png
# data/CameraMask/011469.png
# data/CameraMask/010578.png
# data/CameraMask/018417.png
# data/CameraMask/018093.png
# data/CameraMask/004098.png
# data/CameraMask/003882.png
# data/CameraMask/002991.png
# data/CameraMask/049305.png
# data/CameraMask/008814.png
# data/CameraMask/006870.png
# data/CameraMask/017724.png
# data/CameraMask/010857.png
# data/CameraMask/008571.png
# data/CameraMask/002762.png
# data/CameraMask/008108.png
# data/CameraMask/015236.png
# data/CameraMask/002285.png
# data/CameraMask/049310.png
# data/CameraMask/004067.png
# data/CameraMask/064421.png
# data/CameraMask/014381.png
# data/CameraMask/003851.png
# data/CameraMask/002960.png
# data/CameraMask/049749.png
# data/CameraMask/022247.png
# data/CameraMask/018422.png
# data/CameraMask/013418.png
# data/CameraMask/010583.png
# data/CameraMask/011474.png
# data/CameraMask/064403.png
# data/CameraMask/003833.png
# data/CameraMask/002942.png
# data/CameraMask/008045.png
# data/CameraMask/011771.png
# data/CameraMask/035090.png
# data/CameraMask/006902.png
# data/CameraMask/004085.png
# data/CameraMask/022229.png
# data/CameraMask/018080.png
# data/CameraMask/010565.png
# data/CameraMask/004049.png
# data/CameraMask/000728.png
# data/CameraMask/007352.png
# data/CameraMask/049767.png
# data/CameraMask/010844.png
# data/CameraMask/002744.png
# data/CameraMask/008117.png
# data/CameraMask/004076.png
# data/CameraMask/002294.png
# data/CameraMask/010556.png
# data/CameraMask/003860.png
# data/CameraMask/014390.png
# data/CameraMask/002177.png
# data/CameraMask/049758.png
# data/CameraMask/007343.png
# data/CameraMask/009602.png
# data/CameraMask/012293.png
# data/CameraMask/007820.png
# data/CameraMask/010592.png
# data/CameraMask/018431.png
# data/CameraMask/002735.png
# data/CameraMask/011483.png
# data/CameraMask/003842.png
# data/CameraMask/064412.png
# data/CameraMask/002951.png
# data/CameraMask/002159.png
# data/CameraMask/008054.png
# data/CameraMask/011780.png
# data/CameraMask/022238.png
# data/CameraMask/004094.png
# data/CameraMask/013409.png
# data/CameraMask/010574.png
# data/CameraMask/011465.png
# data/CameraMask/002717.png
# data/CameraMask/004058.png
# data/CameraMask/049301.png
# data/CameraMask/002276.png
# data/CameraMask/010853.png
# data/CameraMask/015227.png
# data/CameraMask/049299.png
# data/CameraMask/008810.png
# data/CameraMask/006883.png
# data/CameraMask/017737.png
# data/CameraMask/007774.png
# data/CameraMask/009556.png
# data/CameraMask/008827.png
# data/CameraMask/008584.png
# data/CameraMask/049318.png
# data/CameraMask/049156.png
# data/CameraMask/014389.png
# data/CameraMask/003859.png
# data/CameraMask/049750.png
# data/CameraMask/007819.png
# data/CameraMask/012033.png
# data/CameraMask/009574.png
# data/CameraMask/049732.png
# data/CameraMask/011061.png
# data/CameraMask/011779.png
# data/CameraMask/022230.png
# data/CameraMask/049174.png
# data/CameraMask/015021.png
# data/CameraMask/018088.png
# data/CameraMask/013401.png
# data/CameraMask/004050.png
# data/CameraMask/003877.png
# data/CameraMask/002115.png
# data/CameraMask/008809.png
# data/CameraMask/049291.png
# data/CameraMask/012024.png
# data/CameraMask/006892.png
# data/CameraMask/001888.png
# data/CameraMask/007783.png
# data/CameraMask/002304.png
# data/CameraMask/011052.png
# data/CameraMask/012499.png
# data/CameraMask/049723.png
# data/CameraMask/049327.png
# data/CameraMask/035089.png
# data/CameraMask/049165.png
# data/CameraMask/015012.png
# data/CameraMask/018079.png
# data/CameraMask/000045.png
# data/CameraMask/010602.png
# data/CameraMask/003868.png
# data/CameraMask/012303.png
# data/CameraMask/002106.png
# data/CameraMask/002959.png
# data/CameraMask/049741.png
# data/CameraMask/049183.png
# data/CameraMask/013410.png
# data/CameraMask/049309.png
# data/CameraMask/049147.png
# data/CameraMask/008098.png
# data/CameraMask/000027.png
# data/CameraMask/002124.png
# data/CameraMask/008575.png
# data/CameraMask/008818.png
# data/CameraMask/008100.png
# data/CameraMask/017728.png
# data/CameraMask/006874.png
# data/CameraMask/004065.png
# data/CameraMask/010860.png
# data/CameraMask/015234.png
# data/CameraMask/008106.png
# data/CameraMask/049189.png
# data/CameraMask/001914.png
# data/CameraMask/022245.png
# data/CameraMask/010581.png
# data/CameraMask/018420.png
# data/CameraMask/013416.png
# data/CameraMask/011472.png
# data/CameraMask/002724.png
# data/CameraMask/049747.png
# data/CameraMask/004083.png
# data/CameraMask/006900.png
# data/CameraMask/010563.png
# data/CameraMask/015018.png
# data/CameraMask/064399.png
# data/CameraMask/049729.png
# data/CameraMask/011058.png
# data/CameraMask/008043.png
# data/CameraMask/006898.png
# data/CameraMask/002940.png
# data/CameraMask/064401.png
# data/CameraMask/007789.png
# data/CameraMask/003831.png
# data/CameraMask/010842.png
# data/CameraMask/001932.png
# data/CameraMask/049288.png
# data/CameraMask/011490.png
# data/CameraMask/049765.png
# data/CameraMask/007350.png
# data/CameraMask/004047.png
# data/CameraMask/002292.png
# data/CameraMask/004074.png
# data/CameraMask/010554.png
# data/CameraMask/015009.png
# data/CameraMask/011049.png
# data/CameraMask/006889.png
# data/CameraMask/008115.png
# data/CameraMask/012291.png
# data/CameraMask/010590.png
# data/CameraMask/011481.png
# data/CameraMask/002733.png
# data/CameraMask/008070.png
# data/CameraMask/007341.png
# data/CameraMask/049756.png
# data/CameraMask/009598.png
# data/CameraMask/000690.png
# data/CameraMask/022236.png
# data/CameraMask/004092.png
# data/CameraMask/001905.png
# data/CameraMask/013407.png
# data/CameraMask/010572.png
# data/CameraMask/015027.png
# data/CameraMask/002715.png
# data/CameraMask/011463.png
# data/CameraMask/002319.png
# data/CameraMask/008052.png
# data/CameraMask/049738.png
# data/CameraMask/003840.png
# data/CameraMask/064410.png
# data/CameraMask/010851.png
# data/CameraMask/049297.png
# data/CameraMask/015225.png
# data/CameraMask/002274.png
# data/CameraMask/004056.png
# data/CameraMask/049316.png
# data/CameraMask/049154.png
# data/CameraMask/000034.png
# data/CameraMask/008582.png
# data/CameraMask/008825.png
# data/CameraMask/009554.png
# data/CameraMask/002768.png
# data/CameraMask/007772.png
# data/CameraMask/006881.png
# data/CameraMask/017735.png
# data/CameraMask/010589.png
# data/CameraMask/018428.png
# data/CameraMask/008069.png
# data/CameraMask/003857.png
# data/CameraMask/014387.png
# data/CameraMask/002966.png
# data/CameraMask/035096.png
# data/CameraMask/049172.png
# data/CameraMask/000689.png
# data/CameraMask/018086.png
# data/CameraMask/011777.png
# data/CameraMask/049730.png
# data/CameraMask/009572.png
# data/CameraMask/003839.png
# data/CameraMask/064409.png
# data/CameraMask/012031.png
# data/CameraMask/002948.png
# data/CameraMask/002113.png
# data/CameraMask/008807.png
# data/CameraMask/003875.png
# data/CameraMask/002984.png
# data/CameraMask/049325.png
# data/CameraMask/049163.png
# data/CameraMask/035087.png
# data/CameraMask/015010.png
# data/CameraMask/018077.png
# data/CameraMask/000043.png
# data/CameraMask/011050.png
# data/CameraMask/011768.png
# data/CameraMask/012497.png
# data/CameraMask/007781.png
# data/CameraMask/009563.png
# data/CameraMask/002939.png
# data/CameraMask/006890.png
# data/CameraMask/012022.png
# data/CameraMask/017744.png
# data/CameraMask/012299.png
# data/CameraMask/011489.png
# data/CameraMask/010598.png
# data/CameraMask/007349.png
# data/CameraMask/012301.png
# data/CameraMask/003866.png
# data/CameraMask/010600.png
# data/CameraMask/049181.png
# data/CameraMask/018095.png
# data/CameraMask/018419.png
# data/CameraMask/011786.png
# data/CameraMask/002320.png
# data/CameraMask/064418.png
# data/CameraMask/014378.png
# data/CameraMask/009581.png
# data/CameraMask/003848.png
# data/CameraMask/008573.png
# data/CameraMask/010859.png
# data/CameraMask/002122.png
# data/CameraMask/002759.png
# data/CameraMask/008816.png
# data/CameraMask/017726.png
# data/CameraMask/006872.png
# data/CameraMask/049145.png
# data/CameraMask/003884.png
# data/CameraMask/049307.png
# data/CameraMask/049150.png
# data/CameraMask/004069.png
# data/CameraMask/002287.png
# data/CameraMask/049312.png
# data/CameraMask/008821.png
# data/CameraMask/002764.png
# data/CameraMask/017731.png
# data/CameraMask/015238.png
# data/CameraMask/011476.png
# data/CameraMask/018424.png
# data/CameraMask/010585.png
# data/CameraMask/007813.png
# data/CameraMask/022249.png
# data/CameraMask/001918.png
# data/CameraMask/003853.png
# data/CameraMask/014383.png
# data/CameraMask/007336.png
# data/CameraMask/008065.png
# data/CameraMask/010567.png
# data/CameraMask/018082.png
# data/CameraMask/035092.png
# data/CameraMask/004087.png
# data/CameraMask/003835.png
# data/CameraMask/064405.png
# data/CameraMask/001891.png
# data/CameraMask/002944.png
# data/CameraMask/011773.png
# data/CameraMask/008047.png
# data/CameraMask/010846.png
# data/CameraMask/001936.png
# data/CameraMask/003871.png
# data/CameraMask/002980.png
# data/CameraMask/007354.png
# data/CameraMask/010558.png
# data/CameraMask/035083.png
# data/CameraMask/049321.png
# data/CameraMask/002296.png
# data/CameraMask/004078.png
# data/CameraMask/008119.png
# data/CameraMask/017740.png
# data/CameraMask/012493.png
# data/CameraMask/002737.png
# data/CameraMask/018433.png
# data/CameraMask/010594.png
# data/CameraMask/012295.png
# data/CameraMask/009604.png
# data/CameraMask/014392.png
# data/CameraMask/003862.png
# data/CameraMask/007345.png
# data/CameraMask/008074.png
# data/CameraMask/002719.png
# data/CameraMask/011467.png
# data/CameraMask/018091.png
# data/CameraMask/010576.png
# data/CameraMask/000694.png
# data/CameraMask/004096.png
# data/CameraMask/064414.png
# data/CameraMask/003844.png
# data/CameraMask/011782.png
# data/CameraMask/002755.png
# data/CameraMask/008812.png
# data/CameraMask/015229.png
# data/CameraMask/010855.png
# data/CameraMask/001945.png
# data/CameraMask/003880.png
# data/CameraMask/049303.png
# data/CameraMask/002278.png
# data/CameraMask/008092.png
# data/CameraMask/004070.png
# data/CameraMask/049158.png
# data/CameraMask/017739.png
# data/CameraMask/012017.png
# data/CameraMask/006885.png
# data/CameraMask/008829.png
# data/CameraMask/009558.png
# data/CameraMask/008111.png
# data/CameraMask/007776.png
# data/CameraMask/011045.png
# data/CameraMask/008586.png
# data/CameraMask/022250.png
# data/CameraMask/049752.png
# data/CameraMask/013403.png
# data/CameraMask/015023.png
# data/CameraMask/022232.png
# data/CameraMask/049176.png
# data/CameraMask/012035.png
# data/CameraMask/011063.png
# data/CameraMask/049734.png
# data/CameraMask/049293.png
# data/CameraMask/015221.png
# data/CameraMask/006867.png
# data/CameraMask/008568.png
# data/CameraMask/002270.png
# data/CameraMask/002988.png
# data/CameraMask/004052.png
# data/CameraMask/003879.png
# data/CameraMask/015014.png
# data/CameraMask/012503.png
# data/CameraMask/049167.png
# data/CameraMask/006894.png
# data/CameraMask/012026.png
# data/CameraMask/049725.png
# data/CameraMask/011054.png
# data/CameraMask/002108.png
# data/CameraMask/010604.png
# data/CameraMask/049761.png
# data/CameraMask/012305.png
# data/CameraMask/013412.png
# data/CameraMask/002720.png
# data/CameraMask/022241.png
# data/CameraMask/049185.png
# data/CameraMask/049743.png
# data/CameraMask/002324.png
# data/CameraMask/002162.png
# data/CameraMask/006876.png
# data/CameraMask/015230.png
# data/CameraMask/008102.png
# data/CameraMask/002126.png
# data/CameraMask/008577.png
# data/CameraMask/004061.png
# data/CameraMask/049149.png
# data/CameraMask/000029.png
# data/CameraMask/022244.png
# data/CameraMask/049188.png
# data/CameraMask/002723.png
# data/CameraMask/011471.png
# data/CameraMask/013415.png
# data/CameraMask/010580.png
# data/CameraMask/049746.png
# data/CameraMask/002165.png
# data/CameraMask/008105.png
# data/CameraMask/006879.png
# data/CameraMask/015233.png
# data/CameraMask/004064.png
# data/CameraMask/010841.png
# data/CameraMask/002741.png
# data/CameraMask/049287.png
# data/CameraMask/049764.png
# data/CameraMask/012308.png
# data/CameraMask/004046.png
# data/CameraMask/008042.png
# data/CameraMask/011057.png
# data/CameraMask/049728.png
# data/CameraMask/003830.png
# data/CameraMask/007788.png
# data/CameraMask/064400.png
# data/CameraMask/012029.png
# data/CameraMask/006897.png
# data/CameraMask/064398.png
# data/CameraMask/015017.png
# data/CameraMask/010562.png
# data/CameraMask/004082.png
# data/CameraMask/022253.png
# data/CameraMask/012290.png
# data/CameraMask/011480.png
# data/CameraMask/002732.png
# data/CameraMask/049755.png
# data/CameraMask/007340.png
# data/CameraMask/002174.png
# data/CameraMask/011048.png
# data/CameraMask/007779.png
# data/CameraMask/008114.png
# data/CameraMask/006888.png
# data/CameraMask/015008.png
# data/CameraMask/004073.png
# data/CameraMask/010850.png
# data/CameraMask/049296.png
# data/CameraMask/015224.png
# data/CameraMask/002273.png
# data/CameraMask/004055.png
# data/CameraMask/049737.png
# data/CameraMask/008051.png
# data/CameraMask/009579.png
# data/CameraMask/015026.png
# data/CameraMask/002714.png
# data/CameraMask/011462.png
# data/CameraMask/010571.png
# data/CameraMask/013406.png
# data/CameraMask/049179.png
# data/CameraMask/004091.png
# data/CameraMask/001904.png
# data/CameraMask/022235.png
# data/CameraMask/012289.png
# data/CameraMask/007816.png
# data/CameraMask/018427.png
# data/CameraMask/010588.png
# data/CameraMask/011479.png
# data/CameraMask/008068.png
# data/CameraMask/007339.png
# data/CameraMask/002965.png
# data/CameraMask/003856.png
# data/CameraMask/014386.png
# data/CameraMask/008581.png
# data/CameraMask/001957.png
# data/CameraMask/017734.png
# data/CameraMask/006880.png
# data/CameraMask/008824.png
# data/CameraMask/009553.png
# data/CameraMask/002767.png
# data/CameraMask/007771.png
# data/CameraMask/000033.png
# data/CameraMask/049315.png
# data/CameraMask/049153.png
# data/CameraMask/002112.png
# data/CameraMask/010849.png
# data/CameraMask/003874.png
# data/CameraMask/011776.png
# data/CameraMask/002947.png
# data/CameraMask/001894.png
# data/CameraMask/012030.png
# data/CameraMask/003838.png
# data/CameraMask/009571.png
# data/CameraMask/064408.png
# data/CameraMask/018085.png
# data/CameraMask/035095.png
# data/CameraMask/000688.png
# data/CameraMask/049171.png
# data/CameraMask/012298.png
# data/CameraMask/010597.png
# data/CameraMask/011488.png
# data/CameraMask/012300.png
# data/CameraMask/007348.png
# data/CameraMask/002974.png
# data/CameraMask/014395.png
# data/CameraMask/003865.png
# data/CameraMask/001966.png
# data/CameraMask/011767.png
# data/CameraMask/012496.png
# data/CameraMask/002301.png
# data/CameraMask/012021.png
# data/CameraMask/017743.png
# data/CameraMask/007780.png
# data/CameraMask/003829.png
# data/CameraMask/009562.png
# data/CameraMask/018076.png
# data/CameraMask/049324.png
# data/CameraMask/049162.png
# data/CameraMask/035086.png
# data/CameraMask/002121.png
# data/CameraMask/010858.png
# data/CameraMask/008572.png
# data/CameraMask/001948.png
# data/CameraMask/017725.png
# data/CameraMask/006871.png
# data/CameraMask/002758.png
# data/CameraMask/008815.png
# data/CameraMask/049306.png
# data/CameraMask/049144.png
# data/CameraMask/003883.png
# data/CameraMask/008059.png
# data/CameraMask/011785.png
# data/CameraMask/064417.png
# data/CameraMask/014377.png
# data/CameraMask/003847.png
# data/CameraMask/009580.png
# data/CameraMask/018418.png
# data/CameraMask/010579.png
# data/CameraMask/018094.png
# data/CameraMask/049180.png
# data/CameraMask/010584.png
# data/CameraMask/018423.png
# data/CameraMask/013419.png
# data/CameraMask/011475.png
# data/CameraMask/022248.png
# data/CameraMask/002961.png
# data/CameraMask/003852.png
# data/CameraMask/014382.png
# data/CameraMask/007335.png
# data/CameraMask/008064.png
# data/CameraMask/002169.png
# data/CameraMask/015237.png
# data/CameraMask/017730.png
# data/CameraMask/008109.png
# data/CameraMask/008820.png
# data/CameraMask/002286.png
# data/CameraMask/049311.png
# data/CameraMask/004068.png
# data/CameraMask/001935.png
# data/CameraMask/010845.png
# data/CameraMask/003870.png
# data/CameraMask/007353.png
# data/CameraMask/049768.png
# data/CameraMask/002943.png
# data/CameraMask/001890.png
# data/CameraMask/003834.png
# data/CameraMask/064404.png
# data/CameraMask/011772.png
# data/CameraMask/008046.png
# data/CameraMask/004086.png
# data/CameraMask/035091.png
# data/CameraMask/010566.png
# data/CameraMask/018081.png
# data/CameraMask/018432.png
# data/CameraMask/010593.png
# data/CameraMask/001926.png
# data/CameraMask/012294.png
# data/CameraMask/002970.png
# data/CameraMask/014391.png
# data/CameraMask/003861.png
# data/CameraMask/049759.png
# data/CameraMask/007344.png
# data/CameraMask/008073.png
# data/CameraMask/008118.png
# data/CameraMask/012492.png
# data/CameraMask/004077.png
# data/CameraMask/049320.png
# data/CameraMask/002295.png
# data/CameraMask/010557.png
# data/CameraMask/015228.png
# data/CameraMask/008811.png
# data/CameraMask/010854.png
# data/CameraMask/004059.png
# data/CameraMask/049302.png
# data/CameraMask/002277.png
# data/CameraMask/008091.png
# data/CameraMask/064413.png
# data/CameraMask/003843.png
# data/CameraMask/011781.png
# data/CameraMask/004095.png
# data/CameraMask/022239.png
# data/CameraMask/000693.png
# data/CameraMask/002718.png
# data/CameraMask/011466.png
# data/CameraMask/018090.png
# data/CameraMask/010575.png
# data/CameraMask/000073.png
# data/CameraMask/002969.png
# data/CameraMask/049751.png
# data/CameraMask/007775.png
# data/CameraMask/008110.png
# data/CameraMask/009557.png
# data/CameraMask/008828.png
# data/CameraMask/006884.png
# data/CameraMask/017738.png
# data/CameraMask/002134.png
# data/CameraMask/008585.png
# data/CameraMask/049157.png
# data/CameraMask/049319.png
# data/CameraMask/049292.png
# data/CameraMask/008567.png
# data/CameraMask/002116.png
# data/CameraMask/003878.png
# data/CameraMask/002987.png
# data/CameraMask/004051.png
# data/CameraMask/012034.png
# data/CameraMask/001898.png
# data/CameraMask/002314.png
# data/CameraMask/011062.png
# data/CameraMask/049733.png
# data/CameraMask/049175.png
# data/CameraMask/022231.png
# data/CameraMask/018089.png
# data/CameraMask/013402.png
# data/CameraMask/015022.png
# data/CameraMask/002107.png
# data/CameraMask/007829.png
# data/CameraMask/003869.png
# data/CameraMask/010603.png
# data/CameraMask/012304.png
# data/CameraMask/049760.png
# data/CameraMask/012025.png
# data/CameraMask/006893.png
# data/CameraMask/001889.png
# data/CameraMask/049724.png
# data/CameraMask/011053.png
# data/CameraMask/049166.png
# data/CameraMask/015013.png
# data/CameraMask/012502.png
# data/CameraMask/008101.png
# data/CameraMask/008819.png
# data/CameraMask/006875.png
# data/CameraMask/017729.png
# data/CameraMask/008576.png
# data/CameraMask/002125.png
# data/CameraMask/049148.png
# data/CameraMask/004060.png
# data/CameraMask/000028.png
# data/CameraMask/008099.png
# data/CameraMask/009584.png
# data/CameraMask/002161.png
# data/CameraMask/049742.png
# data/CameraMask/022240.png
# data/CameraMask/013411.png
# data/CameraMask/064420.png
# data/CameraMask/014380.png
# data/CameraMask/003850.png
# data/CameraMask/049748.png
# data/CameraMask/008062.png
# data/CameraMask/022246.png
# data/CameraMask/001915.png
# data/CameraMask/011473.png
# data/CameraMask/002725.png
# data/CameraMask/010582.png
# data/CameraMask/018421.png
# data/CameraMask/013417.png
# data/CameraMask/004066.png
# data/CameraMask/010861.png
# data/CameraMask/002761.png
# data/CameraMask/008107.png
# data/CameraMask/015235.png
# data/CameraMask/004048.png
# data/CameraMask/049766.png
# data/CameraMask/007351.png
# data/CameraMask/010843.png
# data/CameraMask/049289.png
# data/CameraMask/006901.png
# data/CameraMask/004084.png
# data/CameraMask/015019.png
# data/CameraMask/010564.png
# data/CameraMask/011770.png
# data/CameraMask/008044.png
# data/CameraMask/011059.png
# data/CameraMask/064402.png
# data/CameraMask/003832.png
# data/CameraMask/002941.png
# data/CameraMask/006899.png
# data/CameraMask/009599.png
# data/CameraMask/008071.png
# data/CameraMask/007342.png
# data/CameraMask/049757.png
# data/CameraMask/009601.png
# data/CameraMask/012292.png
# data/CameraMask/011482.png
# data/CameraMask/002734.png
# data/CameraMask/018430.png
# data/CameraMask/010591.png
# data/CameraMask/002293.png
# data/CameraMask/004075.png
# data/CameraMask/010555.png
# data/CameraMask/001960.png
# data/CameraMask/008116.png
# data/CameraMask/049300.png
# data/CameraMask/002275.png
# data/CameraMask/004057.png
# data/CameraMask/010852.png
# data/CameraMask/049298.png
# data/CameraMask/015226.png
# data/CameraMask/001906.png
# data/CameraMask/004093.png
# data/CameraMask/022237.png
# data/CameraMask/000691.png
# data/CameraMask/011464.png
# data/CameraMask/002716.png
# data/CameraMask/015028.png
# data/CameraMask/010573.png
# data/CameraMask/013408.png
# data/CameraMask/008053.png
# data/CameraMask/049739.png
# data/CameraMask/002158.png
# data/CameraMask/003841.png
# data/CameraMask/007799.png
# data/CameraMask/064411.png
# data/CameraMask/002950.png
# data/CameraMask/003858.png
# data/CameraMask/009591.png
# data/CameraMask/014388.png
# data/CameraMask/002967.png
# data/CameraMask/018429.png
# data/CameraMask/049155.png
# data/CameraMask/049317.png
# data/CameraMask/002132.png
# data/CameraMask/008583.png
# data/CameraMask/017736.png
# data/CameraMask/006882.png
# data/CameraMask/007773.png
# data/CameraMask/008826.png
# data/CameraMask/009555.png
# data/CameraMask/003876.png
# data/CameraMask/008088.png
# data/CameraMask/002114.png
# data/CameraMask/049290.png
# data/CameraMask/008808.png
# data/CameraMask/035097.png
# data/CameraMask/049173.png
# data/CameraMask/018087.png
# data/CameraMask/015020.png
# data/CameraMask/049731.png
# data/CameraMask/011778.png
# data/CameraMask/011060.png
# data/CameraMask/002312.png
# data/CameraMask/012032.png
# data/CameraMask/001896.png
# data/CameraMask/002949.png
# data/CameraMask/009573.png
# data/CameraMask/003867.png
# data/CameraMask/010601.png
# data/CameraMask/012302.png
# data/CameraMask/010599.png
# data/CameraMask/049164.png
# data/CameraMask/035088.png
# data/CameraMask/049326.png
# data/CameraMask/018078.png
# data/CameraMask/000044.png
# data/CameraMask/015011.png
# data/CameraMask/002141.png
# data/CameraMask/012498.png
# data/CameraMask/011769.png
# data/CameraMask/011051.png
# data/CameraMask/002303.png
# data/CameraMask/049722.png
# data/CameraMask/006891.png
# data/CameraMask/001887.png
# data/CameraMask/012023.png
# data/CameraMask/009564.png
# data/CameraMask/007782.png
# data/CameraMask/049146.png
# data/CameraMask/049308.png
# data/CameraMask/002994.png
# data/CameraMask/000026.png
# data/CameraMask/002123.png
# data/CameraMask/008574.png
# data/CameraMask/006873.png
# data/CameraMask/017727.png
# data/CameraMask/008817.png
# data/CameraMask/049182.png
# data/CameraMask/018096.png
# data/CameraMask/002321.png
# data/CameraMask/049740.png
# data/CameraMask/002958.png
# data/CameraMask/003849.png
# data/CameraMask/064419.png
# data/CameraMask/014379.png
# data/CameraMask/007337.png
# data/CameraMask/002963.png
# data/CameraMask/014384.png
# data/CameraMask/003854.png
# data/CameraMask/010586.png
# data/CameraMask/018425.png
# data/CameraMask/011477.png
# data/CameraMask/002288.png
# data/CameraMask/049313.png
# data/CameraMask/049151.png
# data/CameraMask/017732.png
# data/CameraMask/015239.png
# data/CameraMask/009551.png
# data/CameraMask/008822.png
# data/CameraMask/008084.png
# data/CameraMask/007355.png
# data/CameraMask/002981.png
# data/CameraMask/003872.png
# data/CameraMask/002747.png
# data/CameraMask/002110.png
# data/CameraMask/007832.png
# data/CameraMask/010847.png
# data/CameraMask/010568.png
# data/CameraMask/018083.png
# data/CameraMask/004088.png
# data/CameraMask/035093.png
# data/CameraMask/001892.png
# data/CameraMask/002945.png
# data/CameraMask/064406.png
# data/CameraMask/003836.png
# data/CameraMask/008048.png
# data/CameraMask/011774.png
# data/CameraMask/007346.png
# data/CameraMask/003863.png
# data/CameraMask/014393.png
# data/CameraMask/010595.png
# data/CameraMask/018434.png
# data/CameraMask/011486.png
# data/CameraMask/002738.png
# data/CameraMask/012296.png
# data/CameraMask/010838.png
# data/CameraMask/010559.png
# data/CameraMask/002297.png
# data/CameraMask/049322.png
# data/CameraMask/004079.png
# data/CameraMask/035084.png
# data/CameraMask/049160.png
# data/CameraMask/017741.png
# data/CameraMask/009560.png
# data/CameraMask/003827.png
# data/CameraMask/012494.png
# data/CameraMask/011765.png
# data/CameraMask/008093.png
# data/CameraMask/049304.png
# data/CameraMask/002279.png
# data/CameraMask/003881.png
# data/CameraMask/017723.png
# data/CameraMask/008813.png
# data/CameraMask/002756.png
# data/CameraMask/008570.png
# data/CameraMask/010856.png
# data/CameraMask/018092.png
# data/CameraMask/018416.png
# data/CameraMask/010577.png
# data/CameraMask/011468.png
# data/CameraMask/004097.png
# data/CameraMask/000695.png
# data/CameraMask/007805.png
# data/CameraMask/002954.png
# data/CameraMask/003845.png
# data/CameraMask/064415.png
# data/CameraMask/011783.png
# data/CameraMask/008057.png
# data/CameraMask/049753.png
# data/CameraMask/009595.png
# data/CameraMask/002730.png
# data/CameraMask/022251.png
# data/CameraMask/000156.png
# data/CameraMask/015006.png
# data/CameraMask/049159.png
# data/CameraMask/004071.png
# data/CameraMask/008112.png
# data/CameraMask/009559.png
# data/CameraMask/007777.png
# data/CameraMask/006886.png
# data/CameraMask/012018.png
# data/CameraMask/015240.png
# data/CameraMask/008587.png
# data/CameraMask/011046.png
# data/CameraMask/004053.png
# data/CameraMask/002271.png
# data/CameraMask/002989.png
# data/CameraMask/006868.png
# data/CameraMask/049294.png
# data/CameraMask/015222.png
# data/CameraMask/008569.png
# data/CameraMask/012513.png
# data/CameraMask/015024.png
# data/CameraMask/002712.png
# data/CameraMask/013404.png
# data/CameraMask/049177.png
# data/CameraMask/022233.png
# data/CameraMask/001902.png
# data/CameraMask/009577.png
# data/CameraMask/012036.png
# data/CameraMask/049735.png
# data/CameraMask/011064.png
# data/CameraMask/049762.png
# data/CameraMask/012306.png
# data/CameraMask/004044.png
# data/CameraMask/049285.png
# data/CameraMask/000084.png
# data/CameraMask/002109.png
# data/CameraMask/064396.png
# data/CameraMask/015015.png
# data/CameraMask/012504.png
# data/CameraMask/010560.png
# data/CameraMask/049168.png
# data/CameraMask/004080.png
# data/CameraMask/009568.png
# data/CameraMask/006895.png
# data/CameraMask/012027.png
# data/CameraMask/011055.png
# data/CameraMask/049726.png
# data/CameraMask/002280.png
# data/CameraMask/004062.png
# data/CameraMask/008103.png
# data/CameraMask/015231.png
# data/CameraMask/006877.png
# data/CameraMask/008578.png
# data/CameraMask/002721.png
# data/CameraMask/013413.png
# data/CameraMask/049186.png
# data/CameraMask/022242.png
# data/CameraMask/002325.png
# data/CameraMask/049744.png
# images/
# images/carseg.png
# images/decoder.png
# images/encoder.png
# images/unet.png
# outputs.py
# test_utils.py

# %% [markdown]
# <a name='2'></a>
# ## 2 - Load and Split the Data

# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import imageio

import matplotlib.pyplot as plt
# %matplotlib inline

path = ''
image_path = os.path.join(path, './data/CameraRGB/')
mask_path = os.path.join(path, './data/CameraMask/')
image_list = os.listdir(image_path)
mask_list = os.listdir(mask_path)
image_list = [image_path+i for i in image_list]
mask_list = [mask_path+i for i in mask_list]

# %% [markdown]
# ### Check out the some of the unmasked and masked images from the dataset:
#
# After you are done exploring, revert back to `N=2`. Otherwise the autograder will throw a `list index out of range` error.

# %%
N = 2
img = imageio.imread(image_list[N])
mask = imageio.imread(mask_list[N])
#mask = np.array([max(mask[i, j]) for i in range(mask.shape[0]) for j in range(mask.shape[1])]).reshape(img.shape[0], img.shape[1])

fig, arr = plt.subplots(1, 2, figsize=(14, 10))
arr[0].imshow(img)
arr[0].set_title('Image')
arr[1].imshow(mask[:, :, 0])
arr[1].set_title('Segmentation')

# %% [markdown]
# <a name='2-1'></a>
# ### 2.1 - Split Your Dataset into Unmasked and Masked Images

# %%
image_list_ds = tf.data.Dataset.list_files(image_list, shuffle=False)
mask_list_ds = tf.data.Dataset.list_files(mask_list, shuffle=False)

for path in zip(image_list_ds.take(3), mask_list_ds.take(3)):
    print(path)

# %%
image_filenames = tf.constant(image_list)
masks_filenames = tf.constant(mask_list)

dataset = tf.data.Dataset.from_tensor_slices((image_filenames, masks_filenames))

for image, mask in dataset.take(1):
    print(image)
    print(mask)

# %% [markdown]
# <a name='2-2'></a>
# ### 2.2 - Preprocess Your Data

# %%
def process_path(image_path, mask_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=3)
    mask = tf.math.reduce_max(mask, axis=-1, keepdims=True)
    return img, mask

def preprocess(image, mask):
    input_image = tf.image.resize(image, (96, 128), method='nearest')
    input_mask = tf.image.resize(mask, (96, 128), method='nearest')

    input_image = input_image / 255.

    return input_image, input_mask

image_ds = dataset.map(process_path)
processed_image_ds = image_ds.map(preprocess)

# %% [markdown]
# <a name='3'></a>
# ## 3 - U-Net
#
# U-Net, named for its U-shape, was originally created in 2015 for tumor detection, but in the years since has become a very popular choice for other semantic segmentation tasks.
#
# U-Net builds on a previous architecture called the Fully Convolutional Network, or FCN, which replaces the dense layers found in a typical CNN with a transposed convolution layer that upsamples the feature map back to the size of the original input image, while preserving the spatial information. This is necessary because the dense layers destroy spatial information (the "where" of the image), which is an essential part of image segmentation tasks. An added bonus of using transpose convolutions is that the input size no longer needs to be fixed, as it does when dense layers are used.
#
# Unfortunately, the final feature layer of the FCN suffers from information loss due to downsampling too much. It then becomes difficult to upsample after so much information has been lost, causing an output that looks rough.
#
# U-Net improves on the FCN, using a somewhat similar design, but differing in some important ways.  Instead of one transposed convolution at the end of the network, it uses a matching number of convolutions for downsampling the input image to a feature map, and transposed convolutions for upsampling those maps back up to the original input image size. It also adds skip connections, to retain information that would otherwise become lost during encoding. Skip connections send information to every upsampling layer in the decoder from the corresponding downsampling layer in the encoder, capturing finer information while also keeping computation low. These help prevent information loss, as well as model overfitting.

# %% [markdown]
# <a name='3-1'></a>
# ### 3.1 - Model Details
#
# <img src="images/unet.png" style="width:700px;height:400;">
# <caption><center> <u><b> Figure 2 </u></b>: U-Net Architecture<br> </center></caption>
#
# **Contracting path** (Encoder containing downsampling steps):
#
# Images are first fed through several convolutional layers which reduce height and width, while growing the number of channels.
#
# The contracting path follows a regular CNN architecture, with convolutional layers, their activations, and pooling layers to downsample the image and extract its features. In detail, it consists of the repeated application of two 3 x 3 unpadded convolutions, each followed by a rectified linear unit (ReLU) and a 2 x 2 max pooling operation with stride 2 for downsampling. At each downsampling step, the number of feature channels is doubled.
#
# **Crop function**: This step crops the image from the contracting path and concatenates it to the current image on the expanding path to create a skip connection.
#
# **Expanding path** (Decoder containing upsampling steps):
#
# The expanding path performs the opposite operation of the contracting path, growing the image back to its original size, while shrinking the channels gradually.
#
# In detail, each step in the expanding path upsamples the feature map, followed by a 2 x 2 convolution (the transposed convolution). This transposed convolution halves the number of feature channels, while growing the height and width of the image.
#
# Next is a concatenation with the correspondingly cropped feature map from the contracting path, and two 3 x 3 convolutions, each followed by a ReLU. You need to perform cropping to handle the loss of border pixels in every convolution.
#
# **Final Feature Mapping Block**: In the final layer, a 1x1 convolution is used to map each 64-component feature vector to the desired number of classes. The channel dimensions from the previous layer correspond to the number of filters used, so when you use 1x1 convolutions, you can transform that dimension by choosing an appropriate number of 1x1 filters. When this idea is applied to the last layer, you can reduce the channel dimensions to have one layer per class.
#
# The U-Net network has 23 convolutional layers in total.

# %% [markdown]
# <a name='3-2'></a>
# ### 3.2 - Encoder (Downsampling Block)
#
# <img src="images/encoder.png" style="width:500px;height:500;">
# <caption><center> <u><b>Figure 3</u></b>: The U-Net Encoder up close <br> </center></caption>
#
# The encoder is a stack of various conv_blocks:
#
# Each `conv_block()` is composed of 2 **Conv2D** layers  with ReLU activations. We will apply **Dropout**, and **MaxPooling2D** to some conv_blocks, as you will verify in the following sections, specifically to the last two blocks of the downsampling.
#
# The function will  return two tensors:
# - `next_layer`: That will go into the next block.
# - `skip_connection`: That will go into the corresponding decoding block.
#
# **Note**: If `max_pooling=True`, the `next_layer` will be the output of the MaxPooling2D layer, but the `skip_connection` will be the output of the previously applied layer(Conv2D or Dropout, depending on the case). Else, both results will be identical.
#
# <a name='ex-1'></a>
# ### Exercise 1 - conv_block
#
# Implement `conv_block(...)`. Here are the instructions for each step in the `conv_block`, or contracting block:
#
# * Add 2 **Conv2D** layers with `n_filters` filters with `kernel_size` set to 3, `kernel_initializer` set to ['he_normal'](https://www.tensorflow.org/api_docs/python/tf/keras/initializers/HeNormal), `padding` set to 'same' and 'relu' activation.
# * if `dropout_prob` > 0, then add a Dropout layer with parameter `dropout_prob`
# * If `max_pooling` is set to True, then add a MaxPooling2D layer with 2x2 pool size

# %%
# UNQ_C1
# GRADED FUNCTION: conv_block
def conv_block(inputs=None, n_filters=32, dropout_prob=0, max_pooling=True):
    """
    Convolutional downsampling block
    
    Arguments:
        inputs -- Input tensor
        n_filters -- Number of filters for the convolutional layers
        dropout_prob -- Dropout probability
        max_pooling -- Use MaxPooling2D to reduce the spatial dimensions of the output volume
    Returns: 
        next_layer, skip_connection --  Next layer and skip connection outputs
    """

    ### START CODE HERE
    conv = Conv2D(None, # Number of filters
                  None,   # Kernel size   
                  activation=None,
                  padding=None,
                  kernel_initializer=None)(inputs)
    conv = Conv2D(None, # Number of filters
                  None,   # Kernel size
                  activation=None,
                  padding=None,
                  kernel_initializer=None)(conv)
    ### END CODE HERE
    
    # if dropout_prob > 0 add a dropout layer, with the variable dropout_prob as parameter
    if dropout_prob > 0:
         ### START CODE HERE
        conv = None
         ### END CODE HERE
         
        
    # if max_pooling is True add a MaxPooling2D with 2x2 pool_size
    if max_pooling:
        ### START CODE HERE
        next_layer = None
        ### END CODE HERE
        
    else:
        next_layer = conv
        
    skip_connection = conv
    
    return next_layer, skip_connection

# %%
input_size=(96, 128, 3)
n_filters = 32
inputs = Input(input_size)
cblock1 = conv_block(inputs, n_filters * 1)
model1 = tf.keras.Model(inputs=inputs, outputs=cblock1)

output1 = [['InputLayer', [(None, 96, 128, 3)], 0],
            ['Conv2D', (None, 96, 128, 32), 896, 'same', 'relu', 'HeNormal'],
            ['Conv2D', (None, 96, 128, 32), 9248, 'same', 'relu', 'HeNormal'],
            ['MaxPooling2D', (None, 48, 64, 32), 0, (2, 2)]]

print('Block 1:')
for layer in summary(model1):
    print(layer)

comparator(summary(model1), output1)

inputs = Input(input_size)
cblock1 = conv_block(inputs, n_filters * 32, dropout_prob=0.1, max_pooling=True)
model2 = tf.keras.Model(inputs=inputs, outputs=cblock1)

output2 = [['InputLayer', [(None, 96, 128, 3)], 0],
            ['Conv2D', (None, 96, 128, 1024), 28672, 'same', 'relu', 'HeNormal'],
            ['Conv2D', (None, 96, 128, 1024), 9438208, 'same', 'relu', 'HeNormal'],
            ['Dropout', (None, 96, 128, 1024), 0, 0.1],
            ['MaxPooling2D', (None, 48, 64, 1024), 0, (2, 2)]]
           
print('\nBlock 2:')   
for layer in summary(model2):
    print(layer)
    
comparator(summary(model2), output2)

# %% [markdown]
# <a name='3-3'></a>
# ### 3.3 - Decoder (Upsampling Block)
#
# The decoder, or upsampling block, upsamples the features back to the original image size. At each upsampling level, you'll take the output of the corresponding encoder block and concatenate it before feeding to the next decoder block.
#
# <img src="images/decoder.png" style="width:500px;height:500;">
# <caption><center> <u><b>Figure 4</u></b>: The U-Net Decoder up close <br> </center></caption>
#
# There are two new components in the decoder: `up` and `merge`. These are the transpose convolution and the skip connections. In addition, there are two more convolutional layers set to the same parameters as in the encoder.
#
# Here you'll encounter the `Conv2DTranspose` layer, which performs the inverse of the `Conv2D` layer. You can read more about it [here.](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2DTranspose)
#
#
# <a name='ex-2'></a>
# ### Exercise 2 - upsampling_block
#
# Implement `upsampling_block(...)`.
#
# For the function `upsampling_block`:
# * Takes the arguments `expansive_input` (which is the input tensor from the previous layer) and `contractive_input` (the input tensor from the previous skip layer)
# * The number of filters here is the same as in the downsampling block you completed previously
# * Your `Conv2DTranspose` layer will take `n_filters` with shape (3,3) and a stride of (2,2), with padding set to `same`. It's applied to `expansive_input`, or the input tensor from the previous layer.
#
# This block is also where you'll concatenate the outputs from the encoder blocks, creating skip connections.
#
# * Concatenate your Conv2DTranspose layer output to the contractive input, with an `axis` of 3. In general, you can concatenate the tensors in the order that you prefer. But for the grader, it is important that you use `[up, contractive_input]`
#
# For the final component, set the parameters for two Conv2D layers to the same values that you set for the two Conv2D layers in the encoder (ReLU activation, He normal initializer, `same` padding).

# %%
# UNQ_C2
# GRADED FUNCTION: upsampling_block
def upsampling_block(expansive_input, contractive_input, n_filters=32):
    """
    Convolutional upsampling block
    
    Arguments:
        expansive_input -- Input tensor from previous layer
        contractive_input -- Input tensor from previous skip layer
        n_filters -- Number of filters for the convolutional layers
    Returns: 
        conv -- Tensor output
    """
    
    ### START CODE HERE
    up = Conv2DTranspose(
                 None,    # number of filters
                 None,    # Kernel size
                 strides=None,
                 padding=None)(expansive_input)
    
    # Merge the previous output and the contractive_input
    merge = concatenate([up, contractive_input], axis=3)
    conv = Conv2D(None,   # Number of filters
                 None,     # Kernel size
                 activation=None,
                 padding=None,
                 kernel_initializer=None)(merge)
    conv = Conv2D(None,  # Number of filters
                 None,   # Kernel size
                 activation=None,
                 padding=None,
                 kernel_initializer=None)(conv)
    ### END CODE HERE
    
    return conv

# %%
input_size1=(12, 16, 256)
input_size2 = (24, 32, 128)
n_filters = 32
expansive_inputs = Input(input_size1)
contractive_inputs =  Input(input_size2)
cblock1 = upsampling_block(expansive_inputs, contractive_inputs, n_filters * 1)
model1 = tf.keras.Model(inputs=[expansive_inputs, contractive_inputs], outputs=cblock1)

output1 = [['InputLayer', [(None, 12, 16, 256)], 0],
            ['Conv2DTranspose', (None, 24, 32, 32), 73760],
            ['InputLayer', [(None, 24, 32, 128)], 0],
            ['Concatenate', (None, 24, 32, 160), 0],
            ['Conv2D', (None, 24, 32, 32), 46112, 'same', 'relu', 'HeNormal'],
            ['Conv2D', (None, 24, 32, 32), 9248, 'same', 'relu', 'HeNormal']]

print('Block 1:')
for layer in summary(model1):
    print(layer)

comparator(summary(model1), output1)

# %% [markdown]
# <a name='3-4'></a>
# ### 3.4 - Build the Model
#
# This is where you'll put it all together, by chaining the encoder, bottleneck, and decoder! You'll need to specify the number of output channels, which for this particular set would be 23. That's because there are 23 possible labels for each pixel in this self-driving car dataset.
#
# <a name='ex-3'></a>
# ### Exercise 3 - unet_model
#
# For the function `unet_model`, specify the input shape, number of filters, and number of classes (23 in this case).
#
# For the first half of the model:
#
# * Begin with a conv block that takes the inputs of the model and the number of filters
# * Then, chain the first output element of each block to the input of the next convolutional block
# * Next, double the number of filters at each step
# * Beginning with `conv_block4`, add `dropout` of 0.3
# * For the final conv_block, set `dropout` to 0.3 again, and turn off max pooling
#
# For the second half:
#
# * Use cblock5 as expansive_input and cblock4 as contractive_input, with `n_filters` * 8. This is your bottleneck layer.
# * Chain the output of the previous block as expansive_input and the corresponding contractive block output.
# * Note that you must use the second element of the contractive block before the max pooling layer.
# * At each step, use half the number of filters of the previous block
# * `conv9` is a Conv2D layer with ReLU activation, He normal initializer, `same` padding
# * Finally, `conv10` is a Conv2D that takes the number of classes as the filter, a kernel size of 1, and "same" padding. The output of `conv10` is the output of your model.

# %%
# UNQ_C3
# GRADED FUNCTION: unet_model
def unet_model(input_size=(96, 128, 3), n_filters=32, n_classes=23):
    """
    Unet model
    
    Arguments:
        input_size -- Input shape 
        n_filters -- Number of filters for the convolutional layers
        n_classes -- Number of output classes
    Returns: 
        model -- tf.keras.Model
    """
    inputs = Input(input_size)
    # Contracting Path (encoding)
    # Add a conv_block with the inputs of the unet_ model and n_filters
    ### START CODE HERE
    cblock1 = conv_block(None, None)
    # Chain the first element of the output of each block to be the input of the next conv_block. 
    # Double the number of filters at each new step
    cblock2 = conv_block(None, None)
    cblock3 = conv_block(None, None)
    cblock4 = conv_block(None, None, dropout=None) # Include a dropout of 0.3 for this layer
    # Include a dropout of 0.3 for this layer, and avoid the max_pooling layer
    cblock5 = conv_block(None, None, dropout=None, max_pooling=None) 
    ### END CODE HERE
    
    # Expanding Path (decoding)
    # Add the first upsampling_block.
    # Use the cblock5[0] as expansive_input and cblock4[1] as contractive_input and n_filters * 8
    ### START CODE HERE
    ublock6 = upsampling_block(None, None,  None)
    # Chain the output of the previous block as expansive_input and the corresponding contractive block output.
    # Note that you must use the second element of the contractive block i.e before the maxpooling layer. 
    # At each step, use half the number of filters of the previous block 
    ublock7 = upsampling_block(None, None,  None)
    ublock8 = upsampling_block(None, None,  None)
    ublock9 = upsampling_block(None, None,  None)
    ### END CODE HERE

    conv9 = Conv2D(n_filters,
                 3,
                 activation='relu',
                 padding='same',
                 kernel_initializer='he_normal')(ublock9)

    # Add a Conv2D layer with n_classes filter, kernel size of 1 and a 'same' padding
    ### START CODE HERE
    conv10 = Conv2D(None, None, padding=None)(conv9)
    ### END CODE HERE
    
    model = tf.keras.Model(inputs=inputs, outputs=conv10)

    return model

# %%
import outputs
img_height = 96
img_width = 128
num_channels = 3

unet = unet_model((img_height, img_width, num_channels))
comparator(summary(unet), outputs.unet_model_output)

# %% [markdown]
# <a name='3-5'></a>
# ### 3.5 - Set Model Dimensions

# %%
img_height = 96
img_width = 128
num_channels = 3

unet = unet_model((img_height, img_width, num_channels))

# %% [markdown]
# ### Check out the model summary below!

# %%
unet.summary()

# %% [markdown]
# <a name='3-6'></a>
# ### 3.6 - Loss Function
#
# In semantic segmentation, you need as many masks as you have object classes. In the dataset you're using, each pixel in every mask has been assigned a single integer probability that it belongs to a certain class, from 0 to num_classes-1. The correct class is the layer with the higher probability.
#
# This is different from categorical crossentropy, where the labels should be one-hot encoded (just 0s and 1s). Here, you'll use sparse categorical crossentropy as your loss function, to perform pixel-wise multiclass prediction. Sparse categorical crossentropy is more efficient than other loss functions when you're dealing with lots of classes.

# %%
unet.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# <a name='3-7'></a>
# ### 3.7 - Dataset Handling
#
# Below, define a function that allows you to display both an input image, and its ground truth: the true mask. The true mask is what your trained model output is aiming to get as close to as possible.

# %%
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

# %%
for image, mask in image_ds.take(1):
    sample_image, sample_mask = image, mask
    print(mask.shape)
display([sample_image, sample_mask])

# %%
for image, mask in processed_image_ds.take(1):
    sample_image, sample_mask = image, mask
    print(mask.shape)
display([sample_image, sample_mask])

# %% [markdown]
# <a name='4'></a>
# ## 4 - Train the Model

# %%
EPOCHS = 40
VAL_SUBSPLITS = 5
BUFFER_SIZE = 500
BATCH_SIZE = 32
processed_image_ds.batch(BATCH_SIZE)
train_dataset = processed_image_ds.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
print(processed_image_ds.element_spec)
model_history = unet.fit(train_dataset, epochs=EPOCHS)

# %% [markdown]
# <a name='4-1'></a>
# ### 4.1 - Create Predicted Masks
#
# Now, define a function that uses `tf.argmax` in the axis of the number of classes to return the index with the largest value and merge the prediction into a single image:

# %%
def create_mask(pred_mask):
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0]

# %% [markdown]
# <a name='4-2'></a>
# ### 4.2 - Plot Model Accuracy
#
# Let's see how your model did!

# %%
plt.plot(model_history.history["accuracy"])

# %% [markdown]
# <a name='4-3'></a>
# ### 4.3 - Show Predictions
#
# Next, check your predicted masks against the true mask and the original input image:

# %%
def show_predictions(dataset=None, num=1):
    """
    Displays the first image of each of the num batches
    """
    if dataset:
        for image, mask in dataset.take(num):
            pred_mask = unet.predict(image)
            display([image[0], mask[0], create_mask(pred_mask)])
    else:
        display([sample_image, sample_mask,
             create_mask(unet.predict(sample_image[tf.newaxis, ...]))])

# %%
show_predictions(train_dataset, 6)

# %% [markdown]
# With 40 epochs you get amazing results!

# %% [markdown]
# ### Conclusion
#
# You've come to the end of this assignment. Awesome work creating a state-of-the art model for semantic image segmentation! This is a very important task for self-driving cars to get right. Elon Musk will surely be knocking down your door at any moment. ;)

# %% [markdown]
# <font color='blue'>
#
# **What you should remember**:
#
# * Semantic image segmentation predicts a label for every single pixel in an image
# * U-Net uses an equal number of convolutional blocks and transposed convolutions for downsampling and upsampling
# * Skip connections are used to prevent border pixel information loss and overfitting in U-Net
